# %%
f = open("./special_str/all_str.txt", encoding="ISO-8859-1")
for ind, line in enumerate(list(f)[30:31]):
    print(ind, line)
    
    if "=&vr=" in line:
        print("find url", line)
        
    for index, li in enumerate(line):
        print(index, li)
        
    with open("./special_str/special_str.txt", "w", encoding="ISO-8859-1") as f:
        f.write(line[0])
    
f.close()
# Out:
# 0 v39-us.tiktokcdn.com/54f296f71d19280b44d2b9a6d5bb04d6/60f67da4/video/tos/useast2a/tos-useast2a-ve-0068c004/87dca93281a84bb5af1c2c5162614be7/?a=1233&br=1922&bt=961&cd=0%7C0%7C1&ch=0&cr=0&cs=0&cv=1&dr=0&ds=3&er=&ft=Qq.UCEXk_4ka&l=20210720013826010189065140552837EF&lr=tiktok_m&mime_type=video_mp4&net=0&pl=0&qs=0&rc=anNzdDs6ZjhlNjMzNzczM0ApMzc5Ojs6OWU6N2U0aDQ5ZWdxZGpmcjRfXm5gLS1kMTZzc18zLS8tYWA2YGNfXjFiYjQ6Yw%3D%3D&vl=&vr=
#
# 0
# 1 v
# 2
# 3 3
# 4
# 5 9
# 6
# 7 -
# 8
# 9 u
# 10
# 11 s
# 12
# 13 .
# 14
# 15 t
# 16
# 17 i
# 18
# 19 k
# 20
# 21 t
# 22
# 23 o
# 24
# 25 k
# 26
# 27 c
# 28
# 29 d
# 30
# 31 n
# 32
# 33 .
# 34
# 35 c
# 36
# 37 o
# 38
# 39 m
# 40
# 41 /
# 42
# 43 5
# 44
# 45 4
# 46
# 47 f
# 48
# 49 2
# 50
# 51 9
# 52
# 53 6
# 54
# 55 f
# 56
# 57 7
# 58
# 59 1
# 60
# 61 d
# 62
# 63 1
# 64
# 65 9
# 66
# 67 2
# 68
# 69 8
# 70
# 71 0
# 72
# 73 b
# 74
# 75 4
# 76
# 77 4
# 78
# 79 d
# 80
# 81 2
# 82
# 83 b
# 84
# 85 9
# 86
# 87 a
# 88
# 89 6
# 90
# 91 d
# 92
# 93 5
# 94
# 95 b
# 96
# ...

# %%
f.close()
